# %%
# import lib
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Loading the csv file
df = pd.read_csv('UnicornCompanies.csv', encoding='cp1252')
df.head()
# Out:
#     Startup Name                  Industry  Founding Year  Unicorn Entry Year  \
# 0  PhysicsWallah                    Edtech         2016.0              2022.0
# 1    LeadSquared                 SaaS- CRM         2011.0              2022.0
# 2     ElasticRun      E-commerce Logistics         2015.0              2022.0
# 3    LEAD School                    Edtech         2012.0              2022.0
# 4        Purplle  E-commerce Personal Care         2012.0              2022.0
#
#     Profit in 2021 Current Valuation  Acquisitions IPO Status
# 0  -$0.877 Million      $1.1 Billion           0.0   Unlisted
# 1      -$1 Million        $1 BIllion           0.0   Unlisted
# 2     -$12 Million      $1.5 Billion           0.0   Unlisted
# 3     -$15 Million      $1.1 Billion           1.0   Unlisted
# 4      -$6 Million      $1.1 Billion           1.0   Unlisted

# %%
# Checking for null values
df.isnull().sum()
# Out:
# Startup Name            0
# Industry                0
# Founding Year         825
# Unicorn Entry Year    825
# Profit in 2021        862
# Current Valuation     825
# Acquisitions          825
# IPO Status            825
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 929 entries, 0 to 928
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Startup Name        929 non-null    object
#  1   Industry            929 non-null    object
#  2   Founding Year       104 non-null    float64
#  3   Unicorn Entry Year  104 non-null    float64
#  4   Profit in 2021      67 non-null     object
#  5   Current Valuation   104 non-null    object
#  6   Acquisitions        104 non-null    float64
#  7   IPO Status          104 non-null    object
# dtypes: float64(3), object(5)
# memory usage: 58.2+ KB

# %%
Value_Missing = df.isnull().sum().sort_values(ascending = False)
percent_missing = (df.isnull().sum() * 100 / len(df)).round(2).sort_values(ascending = False)
missing_data = pd.concat([Value_Missing, percent_missing], axis = 1, keys = ['Total', 'Percent'])
f, ax = plt.subplots(figsize = (20, 5))
plt.xticks(rotation = '90')
cplot = sns.barplot(x = missing_data.index, y = missing_data['Percent'], palette = 'bone_r', lw = 2, ec = 'black')
for count in cplot.patches:
    height = count.get_height()
    ax.annotate('{}'.format(height),xy = (count.get_x() + count.get_width()/2, height),
                    ha = 'center', va = 'bottom', size = 11, xytext = (0,3), textcoords = 'offset points')
cplot.set_title('Missing Value', fontsize = 20, weight = 'bold')
cplot.set_ylabel('Count', fontsize = 15)
cplot.set_xlabel('Features', fontsize = 15);

# %%
df.dropna()
# Out:
#       Startup Name                  Industry  Founding Year  \
# 0    PhysicsWallah                    Edtech         2016.0
# 1      LeadSquared                 SaaS- CRM         2011.0
# 2       ElasticRun      E-commerce Logistics         2015.0
# 3      LEAD School                    Edtech         2012.0
# 4          Purplle  E-commerce Personal Care         2012.0
# ..             ...                       ...            ...
# 98          Zomato                  Foodtech         2008.0
# 99           Paytm        E-commerce Finance         2010.0
# 101       Flipkart                E-commerce         2007.0
# 102         InMobi                    Adtech         2007.0
# 103     MakeMyTrip             Online Travel         2000.0
#
#      Unicorn Entry Year   Profit in 2021 Current Valuation  Acquisitions  \
# 0                2022.0  -$0.877 Million      $1.1 Billion           0.0
# 1                2022.0      -$1 Million        $1 BIllion           0.0
# 2                2022.0     -$12 Million      $1.5 Billion           0.0
# 3                2022.0     -$15 Million      $1.1 Billion           1.0
# 4                2022.0      -$6 Million      $1.1 Billion           1.0
# ..                  ...              ...               ...           ...
# 98               2015.0    -$153 Million      $5.4 Billion          15.0
# 99               2015.0    -$214 Million       $16 Billion          12.0
# 101              2012.0    -$307 Million     $37.6 Billion          18.0
# 102              2011.0      -$9 Million        $1 Billion          10.0
# 103              2010.0     -$56 Million     $2.52 Billion           9.0
#
#     IPO Status
# 0     Unlisted
# 1     Unlisted
# 2     Unlisted
# 3     Unlisted
# 4     Unlisted
# ..         ...
# 98      Listed
# 99      Listed
# 101   Unlisted
# 102   Unlisted
# 103     Listed
#
# [67 rows x 8 columns]
